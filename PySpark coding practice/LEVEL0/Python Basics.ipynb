# %% [markdown]
# 🟢 LEVEL 0: Python Basics (Day 1–3)
#
# Goal: Be comfortable writing & reading basic code.
# - Variables & data types
# - Print / input
# - Type casting
# - Basic operators
#
# Practice
# - Add 2 numbers
# - Check positive/negative
# - Convert string → int safely

# %%
def add_num(a, b):
    return a+b

c = add_num(5,4)
print(c)
